# %% [markdown]
# # Computer Vision Assignment 1 Part 2
# ---
#
# Semester: **Fall 2022**
#
# Due date: **September 29th 2022, 11.59PM EST.**
#
# ## Introduction
# ---
# This assignment requires you to participate in a Kaggle competition with the rest of the class on the [German Traffic Sign Recognition Benchmark](http://benchmark.ini.rub.de/?section=gtsrb). The objective is to produce a model that gives the highest possible accuracy on the test portion of this dataset. You can register for the competition using the private link: https://www.kaggle.com/c/nyu-computer-vision-csci-ga2271-2022/overview.
#
# Skeleton code is provided in the colab below. This contains code for training a simple default model and evaluating it on the test set. The evaluation script produces a file `gtsrb_kaggle.csv` that lists the IDs of the test set images, along with their predicted label. This file should be uploaded to the Kaggle webpage, which will then produce a test accuracy score.
#
# Your goal is to implement a new model architecture that improves upon the baseline performance. You are free to implement any approach covered in class or from research papers. This part will count for 50% of the overall grade for assignment 1. This Grading will depend on your Kaggle performance and rank, as well as novelty of the architecture.
#
# ## Rules
# ---
# You should make a copy of this Colab (`File->Save a copy in Drive`). Please start the assignment early and don’t be afraid to ask for help from either the TAs or myself. You are allowed to collaborate with other students in terms discussing ideas and possible solutions. However you code up the solution yourself, i.e. you must write your own code. Copying your friends code and just changing all the names of the variables is NOT ALLOWED! You are not allowed to use solutions from similar assignments in courses from other institutions, or those found elsewhere on the web.
#
# Your solutions should be submitted via the Brightspace system. This should include a brief description (in the Colab) explaining the model architectures you explored, citing any relevant papers or techniques that you used. You should also include convergence plots of training accuracy vs epoch for relevant models.
#
# ## Important Details
# ---
# • You are only allowed 8 submissions to the Kaggle evaluation server per day. This is to prevent over-fitting on the test dataset. So be sure to start the assignment early!
#
# • You are NOT ALLOWED to use the test set labels during training in any way. Doing so will be regarded as cheating and penalized accordingly.
#
# • The evaluation metric is accuracy, i.e. the fraction of test set examples where the predicted label agrees with the ground truth label.
#
# • You should be able to achieve a test accuracy of at least 95%
#
# • **Extra important:** Please use your NYU NetID as your team name on Kaggle, so the TAs can figure out which user you are on the leaderboard.
#
# # Dataset Preparation
# ___
#
# 1.  Download `dataset.zip` from the course website to your local machine.
# 2.  Unzip the file. You should see a `dataset` directory with three subfolders: `training`, `validation`, and `testing`.
# 3.  Go to Google Drive (on your NYU account) and make a new directory (say `cv_kaggle_assignment`).
# 4.  Upload each of the three subfolders to it.
# 5.  Run the code block below. It will ask for permission to mount your Google Drive (NYU account) so this colab can access it. Paste the authorization code into the box as requested.

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# %cd  /content/drive/'My Drive'/cv_kaggle_assignment/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cv_kaggle_assignment

# %% [markdown]
# # Dataloader

# %%
import torch
from torch.utils.data import Dataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

batch_size = 64
momentum = 0.1
lr = 0.01
epochs = 50
log_interval = 100

class MyDataset(Dataset):

    def __init__(self, X_path="X.pt", y_path="y.pt"):

        self.X = torch.load(X_path).squeeze(1)
        self.y = torch.load(y_path).squeeze(1)
    
    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_dataset = MyDataset(X_path="train/X.pt", y_path="train/y.pt")
val_dataset = MyDataset(X_path="validation/X.pt", y_path="validation/y.pt")

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=True, num_workers=1)

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

nclasses = 43 # GTSRB has 43 classes

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 128, kernel_size=5)
        self.conv2 = nn.Conv2d(128, 256, kernel_size=5)
        self.conv3_drop = nn.Dropout2d()
        self.bn1 = nn.BatchNorm2d(256) 
        self.fc1 = nn.Linear(6400, 50)
        self.fc2 = nn.Linear(50, nclasses)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        #x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.relu(F.max_pool2d(self.conv3_drop(self.conv2(x)), 2))
        x = self.bn1(x)
        x = torch.flatten(x, 1)
        #x = x.view(-1, 500)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x,dim=1)

# %% [markdown]
# # Training

# %%
model = Net()

optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)

def train(epoch):
  model.train()
  correct = 0
  for batch_idx, (data, target) in enumerate(train_loader):
    optimizer.zero_grad()
    output = model(data)
    train_loss = F.nll_loss(output, target)
    train_loss.backward()
    optimizer.step()
    pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
    correct += pred.eq(target.data.view_as(pred)).cpu().sum()
    train_accuracy =  100. * correct / len(train_loader.dataset)
    if batch_idx % log_interval == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}, Accuracy: ({:.0f}%)'.format(epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), train_loss.item(),train_accuracy))
  return train_accuracy
            
def validation():
    model.eval()
    validation_loss = 0
    correct = 0
    for data, target in val_loader:
        output = model(data)
        validation_loss += F.nll_loss(output, target, reduction="sum").item() # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
    validation_loss /= len(val_loader.dataset)
    validation_accuracy = 100. * correct / len(val_loader.dataset)
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        validation_loss, correct, len(val_loader.dataset),
        100. * correct / len(val_loader.dataset)))
    return validation_accuracy


training_accuracy = []
validation_accuracy = []
for epoch in range(1, epochs + 1):
    ta = train(epoch)
    va = validation()
    training_accuracy.append(ta)
    validation_accuracy.append(va)
    model_file = 'model_' + str(epoch) + '.pth'
    torch.save(model.state_dict(), model_file)
    print('\nSaved model to ' + model_file + '.')
# Out:
# Train Epoch: 1 [0/35339 (0%)]	Loss: 3.874046, Accuracy: (0%)
# Train Epoch: 1 [6400/35339 (18%)]	Loss: 2.958927, Accuracy: (3%)
# Train Epoch: 1 [12800/35339 (36%)]	Loss: 2.101048, Accuracy: (10%)
# Train Epoch: 1 [19200/35339 (54%)]	Loss: 1.764509, Accuracy: (20%)
# Train Epoch: 1 [25600/35339 (72%)]	Loss: 1.115906, Accuracy: (32%)
# Train Epoch: 1 [32000/35339 (90%)]	Loss: 0.879397, Accuracy: (45%)
#
# Validation set: Average loss: 1.6771, Accuracy: 2426/3870 (63%)
#
#
# Saved model to model_1.pth.
# Train Epoch: 2 [0/35339 (0%)]	Loss: 0.866568, Accuracy: (0%)
# Train Epoch: 2 [6400/35339 (18%)]	Loss: 0.777253, Accuracy: (15%)
# Train Epoch: 2 [12800/35339 (36%)]	Loss: 0.925762, Accuracy: (29%)
# Train Epoch: 2 [19200/35339 (54%)]	Loss: 0.576750, Accuracy: (45%)
# Train Epoch: 2 [25600/35339 (72%)]	Loss: 0.389405, Accuracy: (60%)
# Train Epoch: 2 [32000/35339 (90%)]	Loss: 0.544337, Accuracy: (76%)
#
# Validation set: Average loss: 0.7940, Accuracy: 3126/3870 (81%)
#
#
# Saved model to model_2.pth.
# Train Epoch: 3 [0/35339 (0%)]	Loss: 0.379923, Accuracy: (0%)
# Train Epoch: 3 [6400/35339 (18%)]	Loss: 0.415150, Accuracy: (16%)
# Train Epoch: 3 [12800/35339 (36%)]	Loss: 0.403293, Accuracy: (33%)
# Train Epoch: 3 [19200/35339 (54%)]	Loss: 0.460207, Accuracy: (49%)
# Train Epoch: 3 [25600/35339 (72%)]	Loss: 0.417951, Accuracy: (66%)
# Train Epoch: 3 [32000/35339 (90%)]	Loss: 0.284404, Accuracy: (82%)
#
# Validation set: Average loss: 1.1570, Accuracy: 2727/3870 (70%)
#
#
# Saved model to model_3.pth.
# Train Epoch: 4 [0/35339 (0%)]	Loss: 0.161960, Accuracy: (0%)
# Train Epoch: 4 [6400/35339 (18%)]	Loss: 0.196349, Accuracy: (17%)
# Train Epoch: 4 [12800/35339 (36%)]	Loss: 0.350231, Accuracy: (34%)
# Train Epoch: 4 [19200/35339 (54%)]	Loss: 0.390029, Accuracy: (51%)
# Train Epoch: 4 [25600/35339 (72%)]	Loss: 0.327696, Accuracy: (68%)
# Train Epoch: 4 [32000/35339 (90%)]	Loss: 0.265350, Accuracy: (85%)
#
# Validation set: Average loss: 0.2905, Accuracy: 3636/3870 (94%)
#
#
# Saved model to model_4.pth.
# Train Epoch: 5 [0/35339 (0%)]	Loss: 0.303916, Accuracy: (0%)
# Train Epoch: 5 [6400/35339 (18%)]	Loss: 0.202053, Accuracy: (17%)
# Train Epoch: 5 [12800/35339 (36%)]	Loss: 0.215301, Accuracy: (34%)
# Train Epoch: 5 [19200/35339 (54%)]	Loss: 0.164352, Accuracy: (52%)
# Train Epoch: 5 [25600/35339 (72%)]	Loss: 0.133351, Accuracy: (69%)
# Train Epoch: 5 [32000/35339 (90%)]	Loss: 0.104913, Accuracy: (86%)
#
# Validation set: Average loss: 0.5009, Accuracy: 3460/3870 (89%)
#
#
# Saved model to model_5.pth.
# Train Epoch: 6 [0/35339 (0%)]	Loss: 0.483119, Accuracy: (0%)
# Train Epoch: 6 [6400/35339 (18%)]	Loss: 0.187241, Accuracy: (17%)
# Train Epoch: 6 [12800/35339 (36%)]	Loss: 0.128643, Accuracy: (35%)
# Train Epoch: 6 [19200/35339 (54%)]	Loss: 0.229477, Accuracy: (52%)
# Train Epoch: 6 [25600/35339 (72%)]	Loss: 0.104470, Accuracy: (70%)
# Train Epoch: 6 [32000/35339 (90%)]	Loss: 0.091742, Accuracy: (87%)
#
# Validation set: Average loss: 0.2523, Accuracy: 3644/3870 (94%)
#
#
# Saved model to model_6.pth.
# Train Epoch: 7 [0/35339 (0%)]	Loss: 0.187372, Accuracy: (0%)
# Train Epoch: 7 [6400/35339 (18%)]	Loss: 0.117357, Accuracy: (18%)
# Train Epoch: 7 [12800/35339 (36%)]	Loss: 0.063705, Accuracy: (35%)
# Train Epoch: 7 [19200/35339 (54%)]	Loss: 0.180682, Accuracy: (53%)
# Train Epoch: 7 [25600/35339 (72%)]	Loss: 0.149352, Accuracy: (70%)
# Train Epoch: 7 [32000/35339 (90%)]	Loss: 0.117768, Accuracy: (88%)
#
# Validation set: Average loss: 0.2187, Accuracy: 3658/3870 (95%)
#
#
# Saved model to model_7.pth.
# Train Epoch: 8 [0/35339 (0%)]	Loss: 0.111861, Accuracy: (0%)
# Train Epoch: 8 [6400/35339 (18%)]	Loss: 0.118994, Accuracy: (18%)
# Train Epoch: 8 [12800/35339 (36%)]	Loss: 0.047635, Accuracy: (35%)
# Train Epoch: 8 [19200/35339 (54%)]	Loss: 0.102692, Accuracy: (53%)
# Train Epoch: 8 [25600/35339 (72%)]	Loss: 0.099604, Accuracy: (70%)
# Train Epoch: 8 [32000/35339 (90%)]	Loss: 0.116807, Accuracy: (88%)
#
# Validation set: Average loss: 0.2472, Accuracy: 3643/3870 (94%)
#
#
# Saved model to model_8.pth.
# Train Epoch: 9 [0/35339 (0%)]	Loss: 0.205453, Accuracy: (0%)
# Train Epoch: 9 [6400/35339 (18%)]	Loss: 0.197679, Accuracy: (18%)
# Train Epoch: 9 [12800/35339 (36%)]	Loss: 0.112036, Accuracy: (35%)
# Train Epoch: 9 [19200/35339 (54%)]	Loss: 0.023422, Accuracy: (53%)
# Train Epoch: 9 [25600/35339 (72%)]	Loss: 0.129831, Accuracy: (71%)
# Train Epoch: 9 [32000/35339 (90%)]	Loss: 0.075555, Accuracy: (88%)
#
# Validation set: Average loss: 0.1645, Accuracy: 3688/3870 (95%)
#
#
# Saved model to model_9.pth.
# Train Epoch: 10 [0/35339 (0%)]	Loss: 0.107479, Accuracy: (0%)
# Train Epoch: 10 [6400/35339 (18%)]	Loss: 0.067255, Accuracy: (18%)
# Train Epoch: 10 [12800/35339 (36%)]	Loss: 0.146159, Accuracy: (36%)
# Train Epoch: 10 [19200/35339 (54%)]	Loss: 0.086600, Accuracy: (53%)
# Train Epoch: 10 [25600/35339 (72%)]	Loss: 0.069828, Accuracy: (71%)
# Train Epoch: 10 [32000/35339 (90%)]	Loss: 0.060397, Accuracy: (89%)
#
# Validation set: Average loss: 0.1431, Accuracy: 3720/3870 (96%)
#
#
# Saved model to model_10.pth.
# Train Epoch: 11 [0/35339 (0%)]	Loss: 0.157954, Accuracy: (0%)
# Train Epoch: 11 [6400/35339 (18%)]	Loss: 0.100031, Accuracy: (18%)
# Train Epoch: 11 [12800/35339 (36%)]	Loss: 0.075986, Accuracy: (36%)
# Train Epoch: 11 [19200/35339 (54%)]	Loss: 0.200700, Accuracy: (53%)
# Train Epoch: 11 [25600/35339 (72%)]	Loss: 0.068987, Accuracy: (71%)
# Train Epoch: 11 [32000/35339 (90%)]	Loss: 0.114221, Accuracy: (89%)
#
# Validation set: Average loss: 0.1419, Accuracy: 3712/3870 (96%)
#
#
# Saved model to model_11.pth.
# Train Epoch: 12 [0/35339 (0%)]	Loss: 0.163753, Accuracy: (0%)
# Train Epoch: 12 [6400/35339 (18%)]	Loss: 0.150470, Accuracy: (18%)
# Train Epoch: 12 [12800/35339 (36%)]	Loss: 0.123677, Accuracy: (36%)
# Train Epoch: 12 [19200/35339 (54%)]	Loss: 0.079124, Accuracy: (53%)
# Train Epoch: 12 [25600/35339 (72%)]	Loss: 0.104083, Accuracy: (71%)
# Train Epoch: 12 [32000/35339 (90%)]	Loss: 0.112483, Accuracy: (89%)
#
# Validation set: Average loss: 0.1728, Accuracy: 3681/3870 (95%)
#
#
# Saved model to model_12.pth.
# Train Epoch: 13 [0/35339 (0%)]	Loss: 0.107192, Accuracy: (0%)
# Train Epoch: 13 [6400/35339 (18%)]	Loss: 0.114163, Accuracy: (18%)
# Train Epoch: 13 [12800/35339 (36%)]	Loss: 0.085096, Accuracy: (36%)
# Train Epoch: 13 [19200/35339 (54%)]	Loss: 0.101338, Accuracy: (53%)
# Train Epoch: 13 [25600/35339 (72%)]	Loss: 0.062515, Accuracy: (71%)
# Train Epoch: 13 [32000/35339 (90%)]	Loss: 0.129260, Accuracy: (89%)
#
# Validation set: Average loss: 0.1583, Accuracy: 3690/3870 (95%)
#
#
# Saved model to model_13.pth.
# Train Epoch: 14 [0/35339 (0%)]	Loss: 0.073923, Accuracy: (0%)
# Train Epoch: 14 [6400/35339 (18%)]	Loss: 0.061959, Accuracy: (18%)
# Train Epoch: 14 [12800/35339 (36%)]	Loss: 0.086215, Accuracy: (36%)
# Train Epoch: 14 [19200/35339 (54%)]	Loss: 0.050495, Accuracy: (53%)
# Train Epoch: 14 [25600/35339 (72%)]	Loss: 0.047288, Accuracy: (71%)
# Train Epoch: 14 [32000/35339 (90%)]	Loss: 0.140629, Accuracy: (89%)
#
# Validation set: Average loss: 0.1490, Accuracy: 3721/3870 (96%)
#
#
# Saved model to model_14.pth.
# Train Epoch: 15 [0/35339 (0%)]	Loss: 0.028668, Accuracy: (0%)
# Train Epoch: 15 [6400/35339 (18%)]	Loss: 0.133932, Accuracy: (18%)
# Train Epoch: 15 [12800/35339 (36%)]	Loss: 0.029184, Accuracy: (36%)
# Train Epoch: 15 [19200/35339 (54%)]	Loss: 0.195750, Accuracy: (53%)
# Train Epoch: 15 [25600/35339 (72%)]	Loss: 0.104647, Accuracy: (71%)
# Train Epoch: 15 [32000/35339 (90%)]	Loss: 0.095161, Accuracy: (89%)
#
# Validation set: Average loss: 0.1274, Accuracy: 3731/3870 (96%)
#
#
# Saved model to model_15.pth.
# Train Epoch: 16 [0/35339 (0%)]	Loss: 0.038712, Accuracy: (0%)
# Train Epoch: 16 [6400/35339 (18%)]	Loss: 0.088234, Accuracy: (18%)
# Train Epoch: 16 [12800/35339 (36%)]	Loss: 0.059351, Accuracy: (36%)
# Train Epoch: 16 [19200/35339 (54%)]	Loss: 0.089446, Accuracy: (54%)
# Train Epoch: 16 [25600/35339 (72%)]	Loss: 0.058336, Accuracy: (71%)
# Train Epoch: 16 [32000/35339 (90%)]	Loss: 0.034971, Accuracy: (89%)
#
# Validation set: Average loss: 0.1189, Accuracy: 3739/3870 (97%)
#
#
# Saved model to model_16.pth.
# Train Epoch: 17 [0/35339 (0%)]	Loss: 0.040233, Accuracy: (0%)
# Train Epoch: 17 [6400/35339 (18%)]	Loss: 0.042796, Accuracy: (18%)
# Train Epoch: 17 [12800/35339 (36%)]	Loss: 0.021215, Accuracy: (36%)
# Train Epoch: 17 [19200/35339 (54%)]	Loss: 0.025363, Accuracy: (54%)
# Train Epoch: 17 [25600/35339 (72%)]	Loss: 0.008914, Accuracy: (71%)
# Train Epoch: 17 [32000/35339 (90%)]	Loss: 0.032661, Accuracy: (89%)
#
# Validation set: Average loss: 0.1312, Accuracy: 3720/3870 (96%)
#
#
# Saved model to model_17.pth.
# Train Epoch: 18 [0/35339 (0%)]	Loss: 0.064553, Accuracy: (0%)
# Train Epoch: 18 [6400/35339 (18%)]	Loss: 0.099116, Accuracy: (18%)
# Train Epoch: 18 [12800/35339 (36%)]	Loss: 0.084167, Accuracy: (36%)
# Train Epoch: 18 [19200/35339 (54%)]	Loss: 0.073429, Accuracy: (54%)
# Train Epoch: 18 [25600/35339 (72%)]	Loss: 0.034140, Accuracy: (72%)
# Train Epoch: 18 [32000/35339 (90%)]	Loss: 0.041254, Accuracy: (89%)
#
# Validation set: Average loss: 0.1240, Accuracy: 3730/3870 (96%)
#
#
# Saved model to model_18.pth.
# Train Epoch: 19 [0/35339 (0%)]	Loss: 0.014668, Accuracy: (0%)
# Train Epoch: 19 [6400/35339 (18%)]	Loss: 0.059943, Accuracy: (18%)
# Train Epoch: 19 [12800/35339 (36%)]	Loss: 0.080900, Accuracy: (36%)
# Train Epoch: 19 [19200/35339 (54%)]	Loss: 0.031268, Accuracy: (54%)
# Train Epoch: 19 [25600/35339 (72%)]	Loss: 0.021126, Accuracy: (71%)
# Train Epoch: 19 [32000/35339 (90%)]	Loss: 0.062900, Accuracy: (89%)
#
# Validation set: Average loss: 0.1138, Accuracy: 3753/3870 (97%)
#
#
# Saved model to model_19.pth.
# Train Epoch: 20 [0/35339 (0%)]	Loss: 0.090606, Accuracy: (0%)
# Train Epoch: 20 [6400/35339 (18%)]	Loss: 0.035037, Accuracy: (18%)
# Train Epoch: 20 [12800/35339 (36%)]	Loss: 0.132385, Accuracy: (36%)
# Train Epoch: 20 [19200/35339 (54%)]	Loss: 0.012237, Accuracy: (54%)
# Train Epoch: 20 [25600/35339 (72%)]	Loss: 0.113431, Accuracy: (72%)
# Train Epoch: 20 [32000/35339 (90%)]	Loss: 0.043322, Accuracy: (89%)
#
# Validation set: Average loss: 0.1184, Accuracy: 3731/3870 (96%)
#
#
# Saved model to model_20.pth.
# Train Epoch: 21 [0/35339 (0%)]	Loss: 0.054365, Accuracy: (0%)
# Train Epoch: 21 [6400/35339 (18%)]	Loss: 0.113683, Accuracy: (18%)
# Train Epoch: 21 [12800/35339 (36%)]	Loss: 0.029587, Accuracy: (36%)
# Train Epoch: 21 [19200/35339 (54%)]	Loss: 0.022650, Accuracy: (54%)
# Train Epoch: 21 [25600/35339 (72%)]	Loss: 0.084625, Accuracy: (72%)
# Train Epoch: 21 [32000/35339 (90%)]	Loss: 0.017131, Accuracy: (90%)
#
# Validation set: Average loss: 0.1235, Accuracy: 3725/3870 (96%)
#
#
# Saved model to model_21.pth.
# Train Epoch: 22 [0/35339 (0%)]	Loss: 0.020820, Accuracy: (0%)
# Train Epoch: 22 [6400/35339 (18%)]	Loss: 0.088338, Accuracy: (18%)
# Train Epoch: 22 [12800/35339 (36%)]	Loss: 0.014203, Accuracy: (36%)
# Train Epoch: 22 [19200/35339 (54%)]	Loss: 0.035077, Accuracy: (54%)
# Train Epoch: 22 [25600/35339 (72%)]	Loss: 0.070549, Accuracy: (72%)
# Train Epoch: 22 [32000/35339 (90%)]	Loss: 0.004419, Accuracy: (89%)
#
# Validation set: Average loss: 0.1369, Accuracy: 3726/3870 (96%)
#
#
# Saved model to model_22.pth.
# Train Epoch: 23 [0/35339 (0%)]	Loss: 0.022919, Accuracy: (0%)
# Train Epoch: 23 [6400/35339 (18%)]	Loss: 0.059055, Accuracy: (18%)
# Train Epoch: 23 [12800/35339 (36%)]	Loss: 0.144399, Accuracy: (36%)
# Train Epoch: 23 [19200/35339 (54%)]	Loss: 0.012263, Accuracy: (54%)
# Train Epoch: 23 [25600/35339 (72%)]	Loss: 0.015678, Accuracy: (72%)
# Train Epoch: 23 [32000/35339 (90%)]	Loss: 0.030309, Accuracy: (90%)
#
# Validation set: Average loss: 0.1188, Accuracy: 3729/3870 (96%)
#
#
# Saved model to model_23.pth.
# Train Epoch: 24 [0/35339 (0%)]	Loss: 0.020927, Accuracy: (0%)
# Train Epoch: 24 [6400/35339 (18%)]	Loss: 0.046031, Accuracy: (18%)
# Train Epoch: 24 [12800/35339 (36%)]	Loss: 0.055583, Accuracy: (36%)
# Train Epoch: 24 [19200/35339 (54%)]	Loss: 0.021790, Accuracy: (54%)
# Train Epoch: 24 [25600/35339 (72%)]	Loss: 0.064187, Accuracy: (72%)
# Train Epoch: 24 [32000/35339 (90%)]	Loss: 0.110162, Accuracy: (90%)
#
# Validation set: Average loss: 0.1079, Accuracy: 3745/3870 (97%)
#
#
# Saved model to model_24.pth.
# Train Epoch: 25 [0/35339 (0%)]	Loss: 0.047420, Accuracy: (0%)
# Train Epoch: 25 [6400/35339 (18%)]	Loss: 0.079825, Accuracy: (18%)
# Train Epoch: 25 [12800/35339 (36%)]	Loss: 0.032491, Accuracy: (36%)
# Train Epoch: 25 [19200/35339 (54%)]	Loss: 0.101076, Accuracy: (54%)
# Train Epoch: 25 [25600/35339 (72%)]	Loss: 0.013747, Accuracy: (72%)
# Train Epoch: 25 [32000/35339 (90%)]	Loss: 0.065330, Accuracy: (90%)
#
# Validation set: Average loss: 0.1280, Accuracy: 3735/3870 (97%)
#
#
# Saved model to model_25.pth.
# Train Epoch: 26 [0/35339 (0%)]	Loss: 0.041064, Accuracy: (0%)
# Train Epoch: 26 [6400/35339 (18%)]	Loss: 0.012070, Accuracy: (18%)
# Train Epoch: 26 [12800/35339 (36%)]	Loss: 0.032762, Accuracy: (36%)
# Train Epoch: 26 [19200/35339 (54%)]	Loss: 0.069348, Accuracy: (54%)
# Train Epoch: 26 [25600/35339 (72%)]	Loss: 0.042278, Accuracy: (72%)
# Train Epoch: 26 [32000/35339 (90%)]	Loss: 0.058846, Accuracy: (90%)
#
# Validation set: Average loss: 0.1281, Accuracy: 3720/3870 (96%)
#
#
# Saved model to model_26.pth.
# Train Epoch: 27 [0/35339 (0%)]	Loss: 0.044952, Accuracy: (0%)
# Train Epoch: 27 [6400/35339 (18%)]	Loss: 0.017698, Accuracy: (18%)
# Train Epoch: 27 [12800/35339 (36%)]	Loss: 0.042683, Accuracy: (36%)
# Train Epoch: 27 [19200/35339 (54%)]	Loss: 0.114738, Accuracy: (54%)
# Train Epoch: 27 [25600/35339 (72%)]	Loss: 0.058937, Accuracy: (72%)
# Train Epoch: 27 [32000/35339 (90%)]	Loss: 0.053901, Accuracy: (90%)
#
# Validation set: Average loss: 0.1366, Accuracy: 3717/3870 (96%)
#
#
# Saved model to model_27.pth.
# Train Epoch: 28 [0/35339 (0%)]	Loss: 0.018292, Accuracy: (0%)
# Train Epoch: 28 [6400/35339 (18%)]	Loss: 0.043970, Accuracy: (18%)
# Train Epoch: 28 [12800/35339 (36%)]	Loss: 0.030965, Accuracy: (36%)
# Train Epoch: 28 [19200/35339 (54%)]	Loss: 0.011074, Accuracy: (54%)
# Train Epoch: 28 [25600/35339 (72%)]	Loss: 0.016141, Accuracy: (72%)
# Train Epoch: 28 [32000/35339 (90%)]	Loss: 0.015333, Accuracy: (90%)
#
# Validation set: Average loss: 0.1178, Accuracy: 3730/3870 (96%)
#
#
# Saved model to model_28.pth.
# Train Epoch: 29 [0/35339 (0%)]	Loss: 0.049369, Accuracy: (0%)
# Train Epoch: 29 [6400/35339 (18%)]	Loss: 0.014996, Accuracy: (18%)
# Train Epoch: 29 [12800/35339 (36%)]	Loss: 0.030052, Accuracy: (36%)
# Train Epoch: 29 [19200/35339 (54%)]	Loss: 0.008646, Accuracy: (54%)
# Train Epoch: 29 [25600/35339 (72%)]	Loss: 0.010427, Accuracy: (72%)
# Train Epoch: 29 [32000/35339 (90%)]	Loss: 0.057208, Accuracy: (90%)
#
# Validation set: Average loss: 0.1291, Accuracy: 3722/3870 (96%)
#
#
# Saved model to model_29.pth.
# Train Epoch: 30 [0/35339 (0%)]	Loss: 0.017463, Accuracy: (0%)
# Train Epoch: 30 [6400/35339 (18%)]	Loss: 0.017226, Accuracy: (18%)
# Train Epoch: 30 [12800/35339 (36%)]	Loss: 0.033234, Accuracy: (36%)
# Train Epoch: 30 [19200/35339 (54%)]	Loss: 0.049398, Accuracy: (54%)
# Train Epoch: 30 [25600/35339 (72%)]	Loss: 0.027725, Accuracy: (72%)
# Train Epoch: 30 [32000/35339 (90%)]	Loss: 0.057103, Accuracy: (90%)
#
# Validation set: Average loss: 0.1409, Accuracy: 3715/3870 (96%)
#
#
# Saved model to model_30.pth.
# Train Epoch: 31 [0/35339 (0%)]	Loss: 0.017357, Accuracy: (0%)
# Train Epoch: 31 [6400/35339 (18%)]	Loss: 0.008766, Accuracy: (18%)
# Train Epoch: 31 [12800/35339 (36%)]	Loss: 0.023129, Accuracy: (36%)
# Train Epoch: 31 [19200/35339 (54%)]	Loss: 0.057927, Accuracy: (54%)
# Train Epoch: 31 [25600/35339 (72%)]	Loss: 0.037446, Accuracy: (72%)
# Train Epoch: 31 [32000/35339 (90%)]	Loss: 0.011531, Accuracy: (90%)
#
# Validation set: Average loss: 0.3377, Accuracy: 3523/3870 (91%)
#
#
# Saved model to model_31.pth.
# Train Epoch: 32 [0/35339 (0%)]	Loss: 0.047145, Accuracy: (0%)
# Train Epoch: 32 [6400/35339 (18%)]	Loss: 0.074187, Accuracy: (18%)
# Train Epoch: 32 [12800/35339 (36%)]	Loss: 0.062202, Accuracy: (36%)
# Train Epoch: 32 [19200/35339 (54%)]	Loss: 0.013256, Accuracy: (54%)
# Train Epoch: 32 [25600/35339 (72%)]	Loss: 0.017212, Accuracy: (72%)
# Train Epoch: 32 [32000/35339 (90%)]	Loss: 0.059195, Accuracy: (90%)
#
# Validation set: Average loss: 0.1126, Accuracy: 3742/3870 (97%)
#
#
# Saved model to model_32.pth.
# Train Epoch: 33 [0/35339 (0%)]	Loss: 0.041605, Accuracy: (0%)
# Train Epoch: 33 [6400/35339 (18%)]	Loss: 0.057895, Accuracy: (18%)
# Train Epoch: 33 [12800/35339 (36%)]	Loss: 0.014658, Accuracy: (36%)
# Train Epoch: 33 [19200/35339 (54%)]	Loss: 0.008058, Accuracy: (54%)
# Train Epoch: 33 [25600/35339 (72%)]	Loss: 0.001274, Accuracy: (72%)
# Train Epoch: 33 [32000/35339 (90%)]	Loss: 0.023556, Accuracy: (90%)
#
# Validation set: Average loss: 0.1142, Accuracy: 3735/3870 (97%)
#
#
# Saved model to model_33.pth.
# Train Epoch: 34 [0/35339 (0%)]	Loss: 0.085753, Accuracy: (0%)
# Train Epoch: 34 [6400/35339 (18%)]	Loss: 0.076503, Accuracy: (18%)
# Train Epoch: 34 [12800/35339 (36%)]	Loss: 0.019581, Accuracy: (36%)
# Train Epoch: 34 [19200/35339 (54%)]	Loss: 0.034192, Accuracy: (54%)
# Train Epoch: 34 [25600/35339 (72%)]	Loss: 0.026926, Accuracy: (72%)
# Train Epoch: 34 [32000/35339 (90%)]	Loss: 0.029332, Accuracy: (90%)
#
# Validation set: Average loss: 0.1116, Accuracy: 3744/3870 (97%)
#
#
# Saved model to model_34.pth.
# Train Epoch: 35 [0/35339 (0%)]	Loss: 0.027883, Accuracy: (0%)
# Train Epoch: 35 [6400/35339 (18%)]	Loss: 0.022651, Accuracy: (18%)
# Train Epoch: 35 [12800/35339 (36%)]	Loss: 0.013093, Accuracy: (36%)
# Train Epoch: 35 [19200/35339 (54%)]	Loss: 0.057613, Accuracy: (54%)
# Train Epoch: 35 [25600/35339 (72%)]	Loss: 0.012056, Accuracy: (72%)
# Train Epoch: 35 [32000/35339 (90%)]	Loss: 0.045491, Accuracy: (90%)
#
# Validation set: Average loss: 0.1255, Accuracy: 3746/3870 (97%)
#
#
# Saved model to model_35.pth.
# Train Epoch: 36 [0/35339 (0%)]	Loss: 0.013798, Accuracy: (0%)
# Train Epoch: 36 [6400/35339 (18%)]	Loss: 0.021516, Accuracy: (18%)
# Train Epoch: 36 [12800/35339 (36%)]	Loss: 0.024113, Accuracy: (36%)
# Train Epoch: 36 [19200/35339 (54%)]	Loss: 0.014832, Accuracy: (54%)
# Train Epoch: 36 [25600/35339 (72%)]	Loss: 0.053778, Accuracy: (72%)
# Train Epoch: 36 [32000/35339 (90%)]	Loss: 0.027981, Accuracy: (90%)
#
# Validation set: Average loss: 0.1240, Accuracy: 3733/3870 (96%)
#
#
# Saved model to model_36.pth.
# Train Epoch: 37 [0/35339 (0%)]	Loss: 0.059224, Accuracy: (0%)
# Train Epoch: 37 [6400/35339 (18%)]	Loss: 0.003747, Accuracy: (18%)
# Train Epoch: 37 [12800/35339 (36%)]	Loss: 0.025080, Accuracy: (36%)
# Train Epoch: 37 [19200/35339 (54%)]	Loss: 0.007439, Accuracy: (54%)
# Train Epoch: 37 [25600/35339 (72%)]	Loss: 0.008414, Accuracy: (72%)
# Train Epoch: 37 [32000/35339 (90%)]	Loss: 0.011374, Accuracy: (90%)
#
# Validation set: Average loss: 0.1495, Accuracy: 3705/3870 (96%)
#
#
# Saved model to model_37.pth.
# Train Epoch: 38 [0/35339 (0%)]	Loss: 0.011371, Accuracy: (0%)
# Train Epoch: 38 [6400/35339 (18%)]	Loss: 0.017636, Accuracy: (18%)
# Train Epoch: 38 [12800/35339 (36%)]	Loss: 0.009238, Accuracy: (36%)
# Train Epoch: 38 [19200/35339 (54%)]	Loss: 0.023781, Accuracy: (54%)
# Train Epoch: 38 [25600/35339 (72%)]	Loss: 0.015990, Accuracy: (72%)
# Train Epoch: 38 [32000/35339 (90%)]	Loss: 0.062864, Accuracy: (90%)
#
# Validation set: Average loss: 0.1096, Accuracy: 3738/3870 (97%)
#
#
# Saved model to model_38.pth.
# Train Epoch: 39 [0/35339 (0%)]	Loss: 0.020274, Accuracy: (0%)
# Train Epoch: 39 [6400/35339 (18%)]	Loss: 0.004139, Accuracy: (18%)
# Train Epoch: 39 [12800/35339 (36%)]	Loss: 0.023147, Accuracy: (36%)
# Train Epoch: 39 [19200/35339 (54%)]	Loss: 0.054043, Accuracy: (54%)
# Train Epoch: 39 [25600/35339 (72%)]	Loss: 0.036978, Accuracy: (72%)
# Train Epoch: 39 [32000/35339 (90%)]	Loss: 0.006372, Accuracy: (90%)
#
# Validation set: Average loss: 0.1097, Accuracy: 3746/3870 (97%)
#
#
# Saved model to model_39.pth.
# Train Epoch: 40 [0/35339 (0%)]	Loss: 0.053134, Accuracy: (0%)
# Train Epoch: 40 [6400/35339 (18%)]	Loss: 0.050155, Accuracy: (18%)
# Train Epoch: 40 [12800/35339 (36%)]	Loss: 0.030922, Accuracy: (36%)
# Train Epoch: 40 [19200/35339 (54%)]	Loss: 0.006614, Accuracy: (54%)
# Train Epoch: 40 [25600/35339 (72%)]	Loss: 0.018550, Accuracy: (72%)
# Train Epoch: 40 [32000/35339 (90%)]	Loss: 0.005554, Accuracy: (90%)
#
# Validation set: Average loss: 0.1222, Accuracy: 3729/3870 (96%)
#
#
# Saved model to model_40.pth.
# Train Epoch: 41 [0/35339 (0%)]	Loss: 0.054083, Accuracy: (0%)
# Train Epoch: 41 [6400/35339 (18%)]	Loss: 0.003830, Accuracy: (18%)
# Train Epoch: 41 [12800/35339 (36%)]	Loss: 0.030853, Accuracy: (36%)
# Train Epoch: 41 [19200/35339 (54%)]	Loss: 0.033137, Accuracy: (54%)
# Train Epoch: 41 [25600/35339 (72%)]	Loss: 0.072419, Accuracy: (72%)
# Train Epoch: 41 [32000/35339 (90%)]	Loss: 0.058734, Accuracy: (90%)
#
# Validation set: Average loss: 0.1949, Accuracy: 3671/3870 (95%)
#
#
# Saved model to model_41.pth.
# Train Epoch: 42 [0/35339 (0%)]	Loss: 0.022998, Accuracy: (0%)
# Train Epoch: 42 [6400/35339 (18%)]	Loss: 0.006007, Accuracy: (18%)
# Train Epoch: 42 [12800/35339 (36%)]	Loss: 0.066226, Accuracy: (36%)
# Train Epoch: 42 [19200/35339 (54%)]	Loss: 0.006908, Accuracy: (54%)
# Train Epoch: 42 [25600/35339 (72%)]	Loss: 0.007337, Accuracy: (72%)
# Train Epoch: 42 [32000/35339 (90%)]	Loss: 0.017200, Accuracy: (90%)
#
# Validation set: Average loss: 0.1209, Accuracy: 3733/3870 (96%)
#
#
# Saved model to model_42.pth.
# Train Epoch: 43 [0/35339 (0%)]	Loss: 0.159909, Accuracy: (0%)
# Train Epoch: 43 [6400/35339 (18%)]	Loss: 0.017594, Accuracy: (18%)
# Train Epoch: 43 [12800/35339 (36%)]	Loss: 0.016773, Accuracy: (36%)
# Train Epoch: 43 [19200/35339 (54%)]	Loss: 0.015848, Accuracy: (54%)
# Train Epoch: 43 [25600/35339 (72%)]	Loss: 0.038974, Accuracy: (72%)
# Train Epoch: 43 [32000/35339 (90%)]	Loss: 0.083251, Accuracy: (90%)
#
# Validation set: Average loss: 0.1139, Accuracy: 3737/3870 (97%)
#
#
# Saved model to model_43.pth.
# Train Epoch: 44 [0/35339 (0%)]	Loss: 0.071451, Accuracy: (0%)
# Train Epoch: 44 [6400/35339 (18%)]	Loss: 0.021830, Accuracy: (18%)
# Train Epoch: 44 [12800/35339 (36%)]	Loss: 0.030625, Accuracy: (36%)
# Train Epoch: 44 [19200/35339 (54%)]	Loss: 0.008354, Accuracy: (54%)
# Train Epoch: 44 [25600/35339 (72%)]	Loss: 0.025167, Accuracy: (72%)
# Train Epoch: 44 [32000/35339 (90%)]	Loss: 0.009713, Accuracy: (90%)
#
# Validation set: Average loss: 0.1096, Accuracy: 3756/3870 (97%)
#
#
# Saved model to model_44.pth.
# Train Epoch: 45 [0/35339 (0%)]	Loss: 0.014460, Accuracy: (0%)
# Train Epoch: 45 [6400/35339 (18%)]	Loss: 0.018800, Accuracy: (18%)
# Train Epoch: 45 [12800/35339 (36%)]	Loss: 0.015375, Accuracy: (36%)
# Train Epoch: 45 [19200/35339 (54%)]	Loss: 0.034884, Accuracy: (54%)
# Train Epoch: 45 [25600/35339 (72%)]	Loss: 0.029140, Accuracy: (72%)
# Train Epoch: 45 [32000/35339 (90%)]	Loss: 0.028779, Accuracy: (90%)
#
# Validation set: Average loss: 0.1113, Accuracy: 3748/3870 (97%)
#
#
# Saved model to model_45.pth.
# Train Epoch: 46 [0/35339 (0%)]	Loss: 0.009768, Accuracy: (0%)
# Train Epoch: 46 [6400/35339 (18%)]	Loss: 0.040096, Accuracy: (18%)
# Train Epoch: 46 [12800/35339 (36%)]	Loss: 0.011880, Accuracy: (36%)
# Train Epoch: 46 [19200/35339 (54%)]	Loss: 0.013112, Accuracy: (54%)
# Train Epoch: 46 [25600/35339 (72%)]	Loss: 0.035333, Accuracy: (72%)
# Train Epoch: 46 [32000/35339 (90%)]	Loss: 0.013779, Accuracy: (90%)
#
# Validation set: Average loss: 0.1308, Accuracy: 3720/3870 (96%)
#
#
# Saved model to model_46.pth.
# Train Epoch: 47 [0/35339 (0%)]	Loss: 0.058087, Accuracy: (0%)
# Train Epoch: 47 [6400/35339 (18%)]	Loss: 0.061485, Accuracy: (18%)
# Train Epoch: 47 [12800/35339 (36%)]	Loss: 0.059626, Accuracy: (36%)
# Train Epoch: 47 [19200/35339 (54%)]	Loss: 0.028421, Accuracy: (54%)
# Train Epoch: 47 [25600/35339 (72%)]	Loss: 0.024210, Accuracy: (72%)
# Train Epoch: 47 [32000/35339 (90%)]	Loss: 0.017021, Accuracy: (90%)
#
# Validation set: Average loss: 0.1279, Accuracy: 3731/3870 (96%)
#
#
# Saved model to model_47.pth.
# Train Epoch: 48 [0/35339 (0%)]	Loss: 0.005161, Accuracy: (0%)
# Train Epoch: 48 [6400/35339 (18%)]	Loss: 0.062297, Accuracy: (18%)
# Train Epoch: 48 [12800/35339 (36%)]	Loss: 0.094573, Accuracy: (36%)
# Train Epoch: 48 [19200/35339 (54%)]	Loss: 0.021353, Accuracy: (54%)
# Train Epoch: 48 [25600/35339 (72%)]	Loss: 0.007357, Accuracy: (72%)
# Train Epoch: 48 [32000/35339 (90%)]	Loss: 0.035353, Accuracy: (90%)
#
# Validation set: Average loss: 0.1170, Accuracy: 3742/3870 (97%)
#
#
# Saved model to model_48.pth.
# Train Epoch: 49 [0/35339 (0%)]	Loss: 0.004664, Accuracy: (0%)
# Train Epoch: 49 [6400/35339 (18%)]	Loss: 0.044778, Accuracy: (18%)
# Train Epoch: 49 [12800/35339 (36%)]	Loss: 0.071560, Accuracy: (36%)
# Train Epoch: 49 [19200/35339 (54%)]	Loss: 0.022156, Accuracy: (54%)
# Train Epoch: 49 [25600/35339 (72%)]	Loss: 0.027894, Accuracy: (72%)
# Train Epoch: 49 [32000/35339 (90%)]	Loss: 0.037427, Accuracy: (90%)
#
# Validation set: Average loss: 0.1383, Accuracy: 3731/3870 (96%)
#
#
# Saved model to model_49.pth.
# Train Epoch: 50 [0/35339 (0%)]	Loss: 0.031871, Accuracy: (0%)
# Train Epoch: 50 [6400/35339 (18%)]	Loss: 0.020090, Accuracy: (18%)
# Train Epoch: 50 [12800/35339 (36%)]	Loss: 0.041750, Accuracy: (36%)
# Train Epoch: 50 [19200/35339 (54%)]	Loss: 0.056052, Accuracy: (54%)
# Train Epoch: 50 [25600/35339 (72%)]	Loss: 0.058205, Accuracy: (72%)
# Train Epoch: 50 [32000/35339 (90%)]	Loss: 0.001656, Accuracy: (90%)
#
# Validation set: Average loss: 0.1247, Accuracy: 3737/3870 (97%)
#
#
# Saved model to model_50.pth.

# %%
import matplotlib.pyplot as plt
epoch = list(range(epochs))
plt.plot(epoch,training_accuracy,label="Training Accuracy")
plt.plot(epoch,validation_accuracy,label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="best")
plt.savefig("picture")
plt.show()

# %%
from torchsummary import summary
summary(model,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 28, 28]           9,728
#             Conv2d-2          [-1, 256, 10, 10]         819,456
#          Dropout2d-3          [-1, 256, 10, 10]               0
#        BatchNorm2d-4            [-1, 256, 5, 5]             512
#             Linear-5                   [-1, 50]         320,050
#             Linear-6                   [-1, 43]           2,193
# ================================================================
# Total params: 1,151,939
# Trainable params: 1,151,939
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.21
# Params size (MB): 4.39
# Estimated Total Size (MB): 5.61
# ----------------------------------------------------------------

# %% [markdown]
# # Evaluate and Submit to Kaggle

# %%
import pickle
import pandas as pd

outfile = 'gtsrb_kaggle.csv'

output_file = open(outfile, "w")
dataframe_dict = {"Filename" : [], "ClassId": []}

test_data = torch.load('testing/test.pt')
file_ids = pickle.load(open('testing/file_ids.pkl', 'rb'))
model.eval() # Don't forget to put your model on eval mode !

for i, data in enumerate(test_data):
    data = data.unsqueeze(0)

    output = model(data)
    pred = output.data.max(1, keepdim=True)[1].item()
    file_id = file_ids[i][0:5]
    dataframe_dict['Filename'].append(file_id)
    dataframe_dict['ClassId'].append(pred)

df = pd.DataFrame(data=dataframe_dict)
df.to_csv(outfile, index=False)
print("Written to csv file {}".format(outfile))
# Out:
# Written to csv file gtsrb_kaggle.csv

# %% [markdown]
# # Submitting to Kaggle
#
# Now download the CSV file `grtsrb_kaggle.csv` from your Google drive and then submit it to Kaggle to check the performance of your model.
